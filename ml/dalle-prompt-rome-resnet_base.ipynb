# %%
import imp
import os
import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
import glob
import cv2
import PIL
import matplotlib.pyplot as plt
from pyMLaux.functions import evaluate_classification_result, plot_history

# %% [markdown]
# # DALLE prompted dataset and rome base line: Resnet Base
# Check for GPU

# %%
tf.get_logger().setLevel('ERROR')

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# Basic constants

# %%
data_dir = "./../data/rome-dalle-prompt"
data_dir_test = "./../data/rome-validation"
batch_size = 16
number_images = 50
image_height = 224
image_width = 224
nr_color_channels = 3
seed = 2023

# %% [markdown]
# Create ImageDataGenerator for data augmentation of training data

# %%
datagen = keras.preprocessing.image.ImageDataGenerator(rescale=(1. / 255),
                                   shear_range=0.1,
                                   zoom_range=0.1,
                                   rotation_range=10,
                                   preprocessing_function=keras.applications.resnet50.preprocess_input,
                                   horizontal_flip=True,
                                   fill_mode='constant',
                                   cval=0)

# %% [markdown]
# Get training data

# %%
img_train = datagen.flow_from_directory(data_dir, target_size=(image_width,image_height), 
                                                    batch_size=batch_size, seed=seed,
                                                    class_mode='categorical')
img_train
# Out:
# Found 1798 images belonging to 5 classes.

# %% [markdown]
# Get test data

# %%
img_test = datagen.flow_from_directory(data_dir_test, target_size=(image_width,image_height), 
                                                    batch_size=batch_size, seed=seed,
                                                    class_mode='categorical')
img_test
# Out:
# Found 50 images belonging to 5 classes.

# %% [markdown]
# Load ResNet50
#
# (approach taken from: https://medium.com/@kenneth.ca95/a-guide-to-transfer-learning-with-keras-using-resnet50-a81a4a28084b)

# %%
input_tensor = keras.Input(shape=(image_height,image_width,nr_color_channels))
resnet50_model = keras.applications.ResNet50(include_top=False,weights="imagenet",input_tensor=input_tensor)

# %%
for layer in resnet50_model.layers[:134]:
    layer.trainable = False

# %%
model = keras.models.Sequential()
model.add(resnet50_model)
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(5,activation='softmax'))

# %% [markdown]
# Create model checkpoints

# %%
filepath = "./" + 'models/dalle_prompt_rome_resnet_base/dalle_prompt_rome_resnet_base_{epoch:02d}-{val_accuracy:.4f}.hdf5'
check_point = tf.keras.callbacks.ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,
                                                save_best_only=True, mode='max')

# %%
callbacks_list = [check_point]

# %%
model.compile(loss='categorical_crossentropy',
                  optimizer=keras.optimizers.RMSprop(learning_rate=2e-5),
                  metrics=['accuracy'])

# %%
history = model.fit(img_train,
                    steps_per_epoch=((len(img_train.filenames)) // batch_size), 
                    epochs=25,
                    validation_data=img_test, 
                    validation_steps=(len(img_test.filenames) // batch_size),
                    callbacks=callbacks_list)
# Out:
# Epoch 1/25
# 112/112 [==============================] - 28s 163ms/step - loss: 2.3538 - accuracy: 0.3805 - val_loss: 1.9119 - val_accuracy: 0.2292
#
# Epoch 00001: val_accuracy improved from -inf to 0.22917, saving model to ./models/dalle_prompt_rome_resnet_base\dalle_prompt_rome_resnet_base_01-0.2292.hdf5
# c:\Users\selin\miniconda3\envs\cov-project\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 2/25
# 112/112 [==============================] - 16s 141ms/step - loss: 1.8086 - accuracy: 0.4545 - val_loss: 1.7996 - val_accuracy: 0.2708
#
# Epoch 00002: val_accuracy improved from 0.22917 to 0.27083, saving model to ./models/dalle_prompt_rome_resnet_base\dalle_prompt_rome_resnet_base_02-0.2708.hdf5
# Epoch 3/25
# 112/112 [==============================] - 16s 144ms/step - loss: 1.6470 - accuracy: 0.4781 - val_loss: 1.9259 - val_accuracy: 0.4375
#
# Epoch 00003: val_accuracy improved from 0.27083 to 0.43750, saving model to ./models/dalle_prompt_rome_resnet_base\dalle_prompt_rome_resnet_base_03-0.4375.hdf5
# Epoch 4/25
# 112/112 [==============================] - 17s 148ms/step - loss: 1.5834 - accuracy: 0.4871 - val_loss: 1.8486 - val_accuracy: 0.4583
#
# Epoch 00004: val_accuracy improved from 0.43750 to 0.45833, saving model to ./models/dalle_prompt_rome_resnet_base\dalle_prompt_rome_resnet_base_04-0.4583.hdf5
# Epoch 5/25
# 112/112 [==============================] - 16s 142ms/step - loss: 1.4743 - accuracy: 0.4989 - val_loss: 1.3616 - val_accuracy: 0.5625
#
# Epoch 00005: val_accuracy improved from 0.45833 to 0.56250, saving model to ./models/dalle_prompt_rome_resnet_base\dalle_prompt_rome_resnet_base_05-0.5625.hdf5
# Epoch 6/25
# 112/112 [==============================] - 16s 141ms/step - loss: 1.3347 - accuracy: 0.5432 - val_loss: 1.5695 - val_accuracy: 0.4583
#
# Epoch 00006: val_accuracy did not improve from 0.56250
# Epoch 7/25
# 112/112 [==============================] - 16s 139ms/step - loss: 1.2484 - accuracy: 0.5589 - val_loss: 1.3303 - val_accuracy: 0.5625
#
# Epoch 00007: val_accuracy did not improve from 0.56250
# Epoch 8/25
# 112/112 [==============================] - 16s 140ms/step - loss: 1.2083 - accuracy: 0.5836 - val_loss: 2.1409 - val_accuracy: 0.3958
#
# Epoch 00008: val_accuracy did not improve from 0.56250
# Epoch 9/25
# 112/112 [==============================] - 16s 140ms/step - loss: 1.1638 - accuracy: 0.5864 - val_loss: 2.0997 - val_accuracy: 0.4583
#
# Epoch 00009: val_accuracy did not improve from 0.56250
# Epoch 10/25
# 112/112 [==============================] - 16s 144ms/step - loss: 1.0837 - accuracy: 0.5971 - val_loss: 1.6688 - val_accuracy: 0.4792
#
# Epoch 00010: val_accuracy did not improve from 0.56250
# Epoch 11/25
# 112/112 [==============================] - 16s 143ms/step - loss: 1.0702 - accuracy: 0.6044 - val_loss: 1.5426 - val_accuracy: 0.5833
#
# Epoch 00011: val_accuracy improved from 0.56250 to 0.58333, saving model to ./models/dalle_prompt_rome_resnet_base\dalle_prompt_rome_resnet_base_11-0.5833.hdf5
# Epoch 12/25
# 112/112 [==============================] - 16s 142ms/step - loss: 1.0214 - accuracy: 0.6274 - val_loss: 2.8809 - val_accuracy: 0.3958
#
# Epoch 00012: val_accuracy did not improve from 0.58333
# Epoch 13/25
# 112/112 [==============================] - 16s 141ms/step - loss: 0.9908 - accuracy: 0.6414 - val_loss: 1.4198 - val_accuracy: 0.5417
#
# Epoch 00013: val_accuracy did not improve from 0.58333
# Epoch 14/25
# 112/112 [==============================] - 16s 140ms/step - loss: 0.9565 - accuracy: 0.6367 - val_loss: 1.9752 - val_accuracy: 0.3542
#
# Epoch 00014: val_accuracy did not improve from 0.58333
# Epoch 15/25
# 112/112 [==============================] - 16s 139ms/step - loss: 0.9151 - accuracy: 0.6599 - val_loss: 1.9862 - val_accuracy: 0.4375
#
# Epoch 00015: val_accuracy did not improve from 0.58333
# Epoch 16/25
# 112/112 [==============================] - 16s 139ms/step - loss: 0.8981 - accuracy: 0.6644 - val_loss: 1.2282 - val_accuracy: 0.5417
#
# Epoch 00016: val_accuracy did not improve from 0.58333
# Epoch 17/25
# 112/112 [==============================] - 16s 140ms/step - loss: 0.8623 - accuracy: 0.6773 - val_loss: 1.4554 - val_accuracy: 0.5833
#
# Epoch 00017: val_accuracy did not improve from 0.58333
# Epoch 18/25
# 112/112 [==============================] - 16s 141ms/step - loss: 0.8505 - accuracy: 0.6706 - val_loss: 1.2947 - val_accuracy: 0.5625
#
# Epoch 00018: val_accuracy did not improve from 0.58333
# Epoch 19/25
# 112/112 [==============================] - 16s 145ms/step - loss: 0.8082 - accuracy: 0.6908 - val_loss: 1.1367 - val_accuracy: 0.6875
#
# Epoch 00019: val_accuracy improved from 0.58333 to 0.68750, saving model to ./models/dalle_prompt_rome_resnet_base\dalle_prompt_rome_resnet_base_19-0.6875.hdf5
# Epoch 20/25
# 112/112 [==============================] - 16s 145ms/step - loss: 0.8017 - accuracy: 0.7048 - val_loss: 1.1985 - val_accuracy: 0.6458
#
# Epoch 00020: val_accuracy did not improve from 0.68750
# Epoch 21/25
# 112/112 [==============================] - 16s 143ms/step - loss: 0.7878 - accuracy: 0.6992 - val_loss: 1.3343 - val_accuracy: 0.4375
#
# Epoch 00021: val_accuracy did not improve from 0.68750
# Epoch 22/25
# 112/112 [==============================] - 16s 144ms/step - loss: 0.7673 - accuracy: 0.7160 - val_loss: 1.5108 - val_accuracy: 0.5833
#
# Epoch 00022: val_accuracy did not improve from 0.68750
# Epoch 23/25
# 112/112 [==============================] - 16s 145ms/step - loss: 0.7275 - accuracy: 0.7189 - val_loss: 1.7544 - val_accuracy: 0.5625
#
# Epoch 00023: val_accuracy did not improve from 0.68750
# Epoch 24/25
# 112/112 [==============================] - 17s 148ms/step - loss: 0.7503 - accuracy: 0.7037 - val_loss: 1.6228 - val_accuracy: 0.6042
#
# Epoch 00024: val_accuracy did not improve from 0.68750
# Epoch 25/25
# 112/112 [==============================] - 16s 143ms/step - loss: 0.7093 - accuracy: 0.7323 - val_loss: 1.8938 - val_accuracy: 0.5833
#
# Epoch 00025: val_accuracy did not improve from 0.68750

# %% [markdown]
# Evaluate model

# %%
plot_history(history)

# %% [markdown]
# Load best model

# %%
model = keras.models.load_model("./models/dalle_prompt_rome_resnet_base/dalle_prompt_rome_resnet_base_19-0.6875.hdf5")
pred = model.predict(img_test, steps=len(img_test.filenames))

# %%
keras.utils.plot_model(model)

# %%
evaluate_classification_result(img_test.classes, pred,classes=["foggy","cloudy","sunny","snowy","rainy"])
# Out:
# [[3 1 1 5 0]
#  [2 2 1 4 1]
#  [6 1 2 1 0]
#  [1 2 1 5 1]
#  [1 2 0 3 4]]
#
#
# Class foggy:
#     Sensitivity (TPR):  30.000% (3 of 10)
#     Specificity (TNR):  75.000% (30 of 40)
#     Precision:          23.077% (3 of 13)
#     Neg. pred. value:   81.081% (30 of 37)
# Class cloudy:
#     Sensitivity (TPR):  20.000% (2 of 10)
#     Specificity (TNR):  85.000% (34 of 40)
#     Precision:          25.000% (2 of 8)
#     Neg. pred. value:   80.952% (34 of 42)
# Class sunny:
#     Sensitivity (TPR):  20.000% (2 of 10)
#     Specificity (TNR):  92.500% (37 of 40)
#     Precision:          40.000% (2 of 5)
#     Neg. pred. value:   82.222% (37 of 45)
# Class snowy:
#     Sensitivity (TPR):  50.000% (5 of 10)
#     Specificity (TNR):  67.500% (27 of 40)
#     Precision:          27.778% (5 of 18)
#     Neg. pred. value:   84.375% (27 of 32)
# Class rainy:
#     Sensitivity (TPR):  40.000% (4 of 10)
#     Specificity (TNR):  95.000% (38 of 40)
#     Precision:          66.667% (4 of 6)
#     Neg. pred. value:   86.364% (38 of 44)
#
# Overall accuracy:   32.000% (16 of 50)
# Balanced accuracy:  32.000%
# array([[3, 1, 1, 5, 0],
#        [2, 2, 1, 4, 1],
#        [6, 1, 2, 1, 0],
#        [1, 2, 1, 5, 1],
#        [1, 2, 0, 3, 4]], dtype=int64)
