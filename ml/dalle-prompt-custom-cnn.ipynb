# %%
import imp
import os
import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
import glob
import cv2
import PIL
import matplotlib.pyplot as plt
from pyMLaux.functions import evaluate_classification_result, plot_history

# %% [markdown]
# # DALLE prompted dataset and rome base line: custom cnn model
# Check for GPU

# %%
tf.get_logger().setLevel('ERROR')

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# Basic constants

# %%
data_dir = "./../data/dalle-prompted-resized"
data_dir_test = "./../data/rome-validation"
batch_size = 16
number_images = 50
image_height = 224
image_width = 224
nr_color_channels = 3
seed = 2023

# %% [markdown]
# Create ImageDataGenerator for data augmentation of training data

# %%
datagen = keras.preprocessing.image.ImageDataGenerator(rescale=(1. / 255),
                                   shear_range=0.1,
                                   zoom_range=0.1,
                                   rotation_range=10,
                                   horizontal_flip=True,
                                   fill_mode='constant',
                                   cval=0)

# %% [markdown]
# Get training data

# %%
img_train = datagen.flow_from_directory(data_dir, target_size=(image_width,image_height), 
                                                    batch_size=batch_size, seed=seed,
                                                    class_mode='categorical')
img_train
# Out:
# Found 1598 images belonging to 5 classes.

# %% [markdown]
# Get test data

# %%
img_test = datagen.flow_from_directory(data_dir_test, target_size=(image_width,image_height), 
                                                    batch_size=batch_size, seed=seed,
                                                    class_mode='categorical')
img_test
# Out:
# Found 50 images belonging to 5 classes.

# %% [markdown]
# Build model
#
# model architecture based on: https://www.kaggle.com/code/tejaswi2003/20bd1a6637-weather-classification-cnn

# %%
model = tf.keras.models.Sequential()
model.add(keras.layers.Conv2D(32,activation="relu",kernel_size=3,input_shape=(image_width, image_height, 3)))
model.add(keras.layers.MaxPooling2D((2,2),padding='same'))
model.add(keras.layers.Conv2D(64,activation="relu",kernel_size=3))
model.add(keras.layers.MaxPooling2D((2,2),padding='same'))
model.add(keras.layers.Conv2D(128,activation="relu",kernel_size=3))
model.add(keras.layers.MaxPooling2D((2,2),padding='same'))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(100,activation="relu"))
model.add(keras.layers.Dense(5,activation="softmax"))

# %% [markdown]
# Create model checkpoints

# %%
filepath = "./" + 'models/dalle_prompt_custom/dalle_prompt_custom_{epoch:02d}-{val_accuracy:.4f}.hdf5'
check_point = tf.keras.callbacks.ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,
                                                save_best_only=True, mode='max')

# %%
callbacks_list = [check_point]

# %%
model.compile(loss='categorical_crossentropy',
                  optimizer=keras.optimizers.RMSprop(learning_rate=2e-5),
                  metrics=['accuracy'])

# %%
history = model.fit(img_train,
                    steps_per_epoch=((len(img_train.filenames)) // batch_size), 
                    epochs=25,
                    validation_data=img_test, 
                    validation_steps=(len(img_test.filenames) // batch_size),
                    callbacks=callbacks_list)
# Out:
# Epoch 1/25
# 99/99 [==============================] - 22s 159ms/step - loss: 1.4590 - accuracy: 0.4083 - val_loss: 1.3472 - val_accuracy: 0.4792
#
# Epoch 00001: val_accuracy improved from -inf to 0.47917, saving model to ./models/dalle_prompt_custom\dalle_prompt_custom_01-0.4792.hdf5
# Epoch 2/25
# 99/99 [==============================] - 15s 147ms/step - loss: 1.1748 - accuracy: 0.5689 - val_loss: 1.2237 - val_accuracy: 0.5208
#
# Epoch 00002: val_accuracy improved from 0.47917 to 0.52083, saving model to ./models/dalle_prompt_custom\dalle_prompt_custom_02-0.5208.hdf5
# Epoch 3/25
# 99/99 [==============================] - 14s 146ms/step - loss: 1.0296 - accuracy: 0.6245 - val_loss: 1.1407 - val_accuracy: 0.6458
#
# Epoch 00003: val_accuracy improved from 0.52083 to 0.64583, saving model to ./models/dalle_prompt_custom\dalle_prompt_custom_03-0.6458.hdf5
# Epoch 4/25
# 99/99 [==============================] - 15s 146ms/step - loss: 0.9447 - accuracy: 0.6498 - val_loss: 1.1141 - val_accuracy: 0.6250
#
# Epoch 00004: val_accuracy did not improve from 0.64583
# Epoch 5/25
# 99/99 [==============================] - 15s 147ms/step - loss: 0.8867 - accuracy: 0.6618 - val_loss: 1.1506 - val_accuracy: 0.6250
#
# Epoch 00005: val_accuracy did not improve from 0.64583
# Epoch 6/25
# 99/99 [==============================] - 14s 146ms/step - loss: 0.8521 - accuracy: 0.6783 - val_loss: 1.1075 - val_accuracy: 0.6250
#
# Epoch 00006: val_accuracy did not improve from 0.64583
# Epoch 7/25
# 99/99 [==============================] - 14s 146ms/step - loss: 0.8381 - accuracy: 0.6820 - val_loss: 1.3834 - val_accuracy: 0.5625
#
# Epoch 00007: val_accuracy did not improve from 0.64583
# Epoch 8/25
# 99/99 [==============================] - 15s 147ms/step - loss: 0.8120 - accuracy: 0.6928 - val_loss: 1.1657 - val_accuracy: 0.6250
#
# Epoch 00008: val_accuracy did not improve from 0.64583
# Epoch 9/25
# 99/99 [==============================] - 14s 143ms/step - loss: 0.7964 - accuracy: 0.6903 - val_loss: 1.1108 - val_accuracy: 0.6875
#
# Epoch 00009: val_accuracy improved from 0.64583 to 0.68750, saving model to ./models/dalle_prompt_custom\dalle_prompt_custom_09-0.6875.hdf5
# Epoch 10/25
# 99/99 [==============================] - 14s 144ms/step - loss: 0.7755 - accuracy: 0.7029 - val_loss: 1.1889 - val_accuracy: 0.5833
#
# Epoch 00010: val_accuracy did not improve from 0.68750
# Epoch 11/25
# 99/99 [==============================] - 14s 140ms/step - loss: 0.7598 - accuracy: 0.7111 - val_loss: 1.0504 - val_accuracy: 0.6875
#
# Epoch 00011: val_accuracy did not improve from 0.68750
# Epoch 12/25
# 99/99 [==============================] - 14s 140ms/step - loss: 0.7455 - accuracy: 0.7149 - val_loss: 1.1770 - val_accuracy: 0.6458
#
# Epoch 00012: val_accuracy did not improve from 0.68750
# Epoch 13/25
# 99/99 [==============================] - 14s 141ms/step - loss: 0.7383 - accuracy: 0.7118 - val_loss: 1.0445 - val_accuracy: 0.6667
#
# Epoch 00013: val_accuracy did not improve from 0.68750
# Epoch 14/25
# 99/99 [==============================] - 14s 143ms/step - loss: 0.7252 - accuracy: 0.7206 - val_loss: 1.0576 - val_accuracy: 0.7292
#
# Epoch 00014: val_accuracy improved from 0.68750 to 0.72917, saving model to ./models/dalle_prompt_custom\dalle_prompt_custom_14-0.7292.hdf5
# Epoch 15/25
# 99/99 [==============================] - 14s 140ms/step - loss: 0.7220 - accuracy: 0.7301 - val_loss: 1.1167 - val_accuracy: 0.6458
#
# Epoch 00015: val_accuracy did not improve from 0.72917
# Epoch 16/25
# 99/99 [==============================] - 14s 140ms/step - loss: 0.7041 - accuracy: 0.7396 - val_loss: 1.2341 - val_accuracy: 0.5625
#
# Epoch 00016: val_accuracy did not improve from 0.72917
# Epoch 17/25
# 99/99 [==============================] - 14s 143ms/step - loss: 0.6938 - accuracy: 0.7421 - val_loss: 1.0521 - val_accuracy: 0.6667
#
# Epoch 00017: val_accuracy did not improve from 0.72917
# Epoch 18/25
# 99/99 [==============================] - 14s 145ms/step - loss: 0.6938 - accuracy: 0.7320 - val_loss: 1.0168 - val_accuracy: 0.6667
#
# Epoch 00018: val_accuracy did not improve from 0.72917
# Epoch 19/25
# 99/99 [==============================] - 14s 139ms/step - loss: 0.6758 - accuracy: 0.7453 - val_loss: 1.1477 - val_accuracy: 0.6458
#
# Epoch 00019: val_accuracy did not improve from 0.72917
# Epoch 20/25
# 99/99 [==============================] - 15s 147ms/step - loss: 0.6733 - accuracy: 0.7446 - val_loss: 0.9319 - val_accuracy: 0.6458
#
# Epoch 00020: val_accuracy did not improve from 0.72917
# Epoch 21/25
# 99/99 [==============================] - 14s 143ms/step - loss: 0.6588 - accuracy: 0.7453 - val_loss: 1.0292 - val_accuracy: 0.6667
#
# Epoch 00021: val_accuracy did not improve from 0.72917
# Epoch 22/25
# 99/99 [==============================] - 14s 140ms/step - loss: 0.6525 - accuracy: 0.7579 - val_loss: 1.1007 - val_accuracy: 0.6250
#
# Epoch 00022: val_accuracy did not improve from 0.72917
# Epoch 23/25
# 99/99 [==============================] - 14s 139ms/step - loss: 0.6367 - accuracy: 0.7661 - val_loss: 1.2711 - val_accuracy: 0.5208
#
# Epoch 00023: val_accuracy did not improve from 0.72917
# Epoch 24/25
# 99/99 [==============================] - 14s 140ms/step - loss: 0.6397 - accuracy: 0.7579 - val_loss: 1.2079 - val_accuracy: 0.6667
#
# Epoch 00024: val_accuracy did not improve from 0.72917
# Epoch 25/25
# 99/99 [==============================] - 14s 140ms/step - loss: 0.6298 - accuracy: 0.7623 - val_loss: 1.2696 - val_accuracy: 0.6667
#
# Epoch 00025: val_accuracy did not improve from 0.72917

# %% [markdown]
# Evaluate model

# %%
plot_history(history)

# %% [markdown]
# Load best model

# %%
model = keras.models.load_model("./models/dalle_prompt_custom/dalle_prompt_custom_14-0.7292.hdf5")
pred = model.predict(img_test, steps=len(img_test.filenames))

# %%
keras.utils.plot_model(model)

# %%
evaluate_classification_result(img_test.classes, pred,classes=["foggy","cloudy","sunny","snowy","rainy"])
# Out:
# [[2 2 1 3 2]
#  [2 2 1 4 1]
#  [6 1 1 1 1]
#  [4 2 0 3 1]
#  [2 2 0 4 2]]
#
#
# Class foggy:
#     Sensitivity (TPR):  20.000% (2 of 10)
#     Specificity (TNR):  65.000% (26 of 40)
#     Precision:          12.500% (2 of 16)
#     Neg. pred. value:   76.471% (26 of 34)
# Class cloudy:
#     Sensitivity (TPR):  20.000% (2 of 10)
#     Specificity (TNR):  82.500% (33 of 40)
#     Precision:          22.222% (2 of 9)
#     Neg. pred. value:   80.488% (33 of 41)
# Class sunny:
#     Sensitivity (TPR):  10.000% (1 of 10)
#     Specificity (TNR):  95.000% (38 of 40)
#     Precision:          33.333% (1 of 3)
#     Neg. pred. value:   80.851% (38 of 47)
# Class snowy:
#     Sensitivity (TPR):  30.000% (3 of 10)
#     Specificity (TNR):  70.000% (28 of 40)
#     Precision:          20.000% (3 of 15)
#     Neg. pred. value:   80.000% (28 of 35)
# Class rainy:
#     Sensitivity (TPR):  20.000% (2 of 10)
#     Specificity (TNR):  87.500% (35 of 40)
#     Precision:          28.571% (2 of 7)
#     Neg. pred. value:   81.395% (35 of 43)
#
# Overall accuracy:   20.000% (10 of 50)
# Balanced accuracy:  20.000%
# array([[2, 2, 1, 3, 2],
#        [2, 2, 1, 4, 1],
#        [6, 1, 1, 1, 1],
#        [4, 2, 0, 3, 1],
#        [2, 2, 0, 4, 2]], dtype=int64)
