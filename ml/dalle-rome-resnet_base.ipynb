# %%
import imp
import os
import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
import glob
import cv2
import PIL
import matplotlib.pyplot as plt
from pyMLaux.functions import evaluate_classification_result, plot_history

# %% [markdown]
# # DALLE both datasets and rome base base line: Resnet Base
# Check for GPU

# %%
tf.get_logger().setLevel('ERROR')

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# Basic constants

# %%
data_dir = "./../data/rome-dalle-variation-prompt"
data_dir_test = "./../data/rome-validation"
batch_size = 16
number_images = 50
image_height = 224
image_width = 224
nr_color_channels = 3
seed = 2023

# %% [markdown]
# Create ImageDataGenerator for data augmentation of training data

# %%
datagen = keras.preprocessing.image.ImageDataGenerator(rescale=(1. / 255),
                                   shear_range=0.1,
                                   zoom_range=0.1,
                                   rotation_range=10,
                                   preprocessing_function=keras.applications.resnet50.preprocess_input,
                                   horizontal_flip=True,
                                   fill_mode='constant',
                                   cval=0)

# %% [markdown]
# Get training data

# %%
img_train = datagen.flow_from_directory(data_dir, target_size=(image_width,image_height), 
                                                    batch_size=batch_size, seed=seed,
                                                    class_mode='categorical')
img_train
# Out:
# Found 3003 images belonging to 5 classes.

# %% [markdown]
# Get test data

# %%
img_test = datagen.flow_from_directory(data_dir_test, target_size=(image_width,image_height), 
                                                    batch_size=batch_size, seed=seed,
                                                    class_mode='categorical')
img_test
# Out:
# Found 50 images belonging to 5 classes.

# %% [markdown]
# Load ResNet50
#
# (approach taken from: https://medium.com/@kenneth.ca95/a-guide-to-transfer-learning-with-keras-using-resnet50-a81a4a28084b)

# %%
input_tensor = keras.Input(shape=(image_height,image_width,nr_color_channels))
resnet50_model = keras.applications.ResNet50(include_top=False,weights="imagenet",input_tensor=input_tensor)

# %%
for layer in resnet50_model.layers[:134]:
    layer.trainable = False

# %%
model = keras.models.Sequential()
model.add(resnet50_model)
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(5,activation='softmax'))

# %% [markdown]
# Create model checkpoints

# %%
filepath = "./" + 'models/dalle_rome_resnet_base/dalle_rome_resnet_base_{epoch:02d}-{val_accuracy:.4f}.hdf5'
check_point = tf.keras.callbacks.ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,
                                                save_best_only=True, mode='max')

# %%
callbacks_list = [check_point]

# %%
model.compile(loss='categorical_crossentropy',
                  optimizer=keras.optimizers.RMSprop(learning_rate=2e-5),
                  metrics=['accuracy'])

# %%
history = model.fit(img_train,
                    steps_per_epoch=((len(img_train.filenames)) // batch_size), 
                    epochs=25,
                    validation_data=img_test, 
                    validation_steps=(len(img_test.filenames) // batch_size),
                    callbacks=callbacks_list)
# Out:
# Epoch 1/25
# 187/187 [==============================] - 52s 221ms/step - loss: 1.9491 - accuracy: 0.4399 - val_loss: 1.9922 - val_accuracy: 0.2083
#
# Epoch 00001: val_accuracy improved from -inf to 0.20833, saving model to ./models/dalle_rome_resnet_base\dalle_rome_resnet_base_01-0.2083.hdf5
# c:\Users\selin\miniconda3\envs\cov-project\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 2/25
# 187/187 [==============================] - 38s 204ms/step - loss: 1.5602 - accuracy: 0.5099 - val_loss: 1.4964 - val_accuracy: 0.4792
#
# Epoch 00002: val_accuracy improved from 0.20833 to 0.47917, saving model to ./models/dalle_rome_resnet_base\dalle_rome_resnet_base_02-0.4792.hdf5
# Epoch 3/25
# 187/187 [==============================] - 28s 149ms/step - loss: 1.3479 - accuracy: 0.5460 - val_loss: 1.4240 - val_accuracy: 0.4792
#
# Epoch 00003: val_accuracy did not improve from 0.47917
# Epoch 4/25
# 187/187 [==============================] - 27s 144ms/step - loss: 1.2252 - accuracy: 0.5705 - val_loss: 1.9149 - val_accuracy: 0.5208
#
# Epoch 00004: val_accuracy improved from 0.47917 to 0.52083, saving model to ./models/dalle_rome_resnet_base\dalle_rome_resnet_base_04-0.5208.hdf5
# Epoch 5/25
# 187/187 [==============================] - 28s 147ms/step - loss: 1.1524 - accuracy: 0.5922 - val_loss: 2.2140 - val_accuracy: 0.4167
#
# Epoch 00005: val_accuracy did not improve from 0.52083
# Epoch 6/25
# 187/187 [==============================] - 29s 155ms/step - loss: 1.0397 - accuracy: 0.6220 - val_loss: 1.5700 - val_accuracy: 0.5833
#
# Epoch 00006: val_accuracy improved from 0.52083 to 0.58333, saving model to ./models/dalle_rome_resnet_base\dalle_rome_resnet_base_06-0.5833.hdf5
# Epoch 7/25
# 187/187 [==============================] - 29s 152ms/step - loss: 0.9680 - accuracy: 0.6478 - val_loss: 2.1406 - val_accuracy: 0.4375
#
# Epoch 00007: val_accuracy did not improve from 0.58333
# Epoch 8/25
# 187/187 [==============================] - 29s 156ms/step - loss: 0.9121 - accuracy: 0.6662 - val_loss: 1.7324 - val_accuracy: 0.5000
#
# Epoch 00008: val_accuracy did not improve from 0.58333
# Epoch 9/25
# 187/187 [==============================] - 27s 143ms/step - loss: 0.8900 - accuracy: 0.6753 - val_loss: 1.5231 - val_accuracy: 0.5833
#
# Epoch 00009: val_accuracy did not improve from 0.58333
# Epoch 10/25
# 187/187 [==============================] - 27s 143ms/step - loss: 0.8448 - accuracy: 0.6900 - val_loss: 2.6885 - val_accuracy: 0.4583
#
# Epoch 00010: val_accuracy did not improve from 0.58333
# Epoch 11/25
# 187/187 [==============================] - 27s 142ms/step - loss: 0.8094 - accuracy: 0.6913 - val_loss: 1.6245 - val_accuracy: 0.6042
#
# Epoch 00011: val_accuracy improved from 0.58333 to 0.60417, saving model to ./models/dalle_rome_resnet_base\dalle_rome_resnet_base_11-0.6042.hdf5
# Epoch 12/25
# 187/187 [==============================] - 27s 142ms/step - loss: 0.7658 - accuracy: 0.7144 - val_loss: 1.2005 - val_accuracy: 0.7083
#
# Epoch 00012: val_accuracy improved from 0.60417 to 0.70833, saving model to ./models/dalle_rome_resnet_base\dalle_rome_resnet_base_12-0.7083.hdf5
# Epoch 13/25
# 187/187 [==============================] - 26s 141ms/step - loss: 0.7583 - accuracy: 0.7288 - val_loss: 1.4620 - val_accuracy: 0.6250
#
# Epoch 00013: val_accuracy did not improve from 0.70833
# Epoch 14/25
# 187/187 [==============================] - 26s 140ms/step - loss: 0.7352 - accuracy: 0.7245 - val_loss: 1.8518 - val_accuracy: 0.4792
#
# Epoch 00014: val_accuracy did not improve from 0.70833
# Epoch 15/25
# 187/187 [==============================] - 30s 162ms/step - loss: 0.6912 - accuracy: 0.7345 - val_loss: 2.1652 - val_accuracy: 0.4792
#
# Epoch 00015: val_accuracy did not improve from 0.70833
# Epoch 16/25
# 187/187 [==============================] - 28s 151ms/step - loss: 0.6626 - accuracy: 0.7503 - val_loss: 1.1132 - val_accuracy: 0.6667
#
# Epoch 00016: val_accuracy did not improve from 0.70833
# Epoch 17/25
# 187/187 [==============================] - 27s 143ms/step - loss: 0.6456 - accuracy: 0.7506 - val_loss: 1.3929 - val_accuracy: 0.5833
#
# Epoch 00017: val_accuracy did not improve from 0.70833
# Epoch 18/25
# 187/187 [==============================] - 27s 142ms/step - loss: 0.6536 - accuracy: 0.7543 - val_loss: 1.2443 - val_accuracy: 0.6667
#
# Epoch 00018: val_accuracy did not improve from 0.70833
# Epoch 19/25
# 187/187 [==============================] - 27s 142ms/step - loss: 0.6367 - accuracy: 0.7573 - val_loss: 2.8486 - val_accuracy: 0.5417
#
# Epoch 00019: val_accuracy did not improve from 0.70833
# Epoch 20/25
# 187/187 [==============================] - 27s 142ms/step - loss: 0.6291 - accuracy: 0.7734 - val_loss: 1.2089 - val_accuracy: 0.6042
#
# Epoch 00020: val_accuracy did not improve from 0.70833
# Epoch 21/25
# 187/187 [==============================] - 26s 141ms/step - loss: 0.5874 - accuracy: 0.7774 - val_loss: 2.3630 - val_accuracy: 0.5208
#
# Epoch 00021: val_accuracy did not improve from 0.70833
# Epoch 22/25
# 187/187 [==============================] - 26s 141ms/step - loss: 0.5766 - accuracy: 0.7817 - val_loss: 2.1089 - val_accuracy: 0.5000
#
# Epoch 00022: val_accuracy did not improve from 0.70833
# Epoch 23/25
# 187/187 [==============================] - 26s 141ms/step - loss: 0.5548 - accuracy: 0.7861 - val_loss: 1.4531 - val_accuracy: 0.6458
#
# Epoch 00023: val_accuracy did not improve from 0.70833
# Epoch 24/25
# 187/187 [==============================] - 26s 141ms/step - loss: 0.5356 - accuracy: 0.8018 - val_loss: 1.4446 - val_accuracy: 0.5625
#
# Epoch 00024: val_accuracy did not improve from 0.70833
# Epoch 25/25
# 187/187 [==============================] - 26s 141ms/step - loss: 0.5525 - accuracy: 0.7881 - val_loss: 1.5266 - val_accuracy: 0.6458
#
# Epoch 00025: val_accuracy did not improve from 0.70833

# %% [markdown]
# Evaluate model

# %%
plot_history(history)

# %% [markdown]
# Load best model

# %%
model = keras.models.load_model("./models/dalle_rome_resnet_base/dalle_rome_resnet_base_12-0.7083.hdf5")
pred = model.predict(img_test, steps=len(img_test.filenames))

# %%
keras.utils.plot_model(model)

# %%
evaluate_classification_result(img_test.classes, pred,classes=["foggy","cloudy","sunny","snowy","rainy"])
# Out:
# [[4 2 0 2 2]
#  [2 1 1 4 2]
#  [6 1 1 1 1]
#  [4 2 0 3 1]
#  [3 1 0 2 4]]
#
#
# Class foggy:
#     Sensitivity (TPR):  40.000% (4 of 10)
#     Specificity (TNR):  62.500% (25 of 40)
#     Precision:          21.053% (4 of 19)
#     Neg. pred. value:   80.645% (25 of 31)
# Class cloudy:
#     Sensitivity (TPR):  10.000% (1 of 10)
#     Specificity (TNR):  85.000% (34 of 40)
#     Precision:          14.286% (1 of 7)
#     Neg. pred. value:   79.070% (34 of 43)
# Class sunny:
#     Sensitivity (TPR):  10.000% (1 of 10)
#     Specificity (TNR):  97.500% (39 of 40)
#     Precision:          50.000% (1 of 2)
#     Neg. pred. value:   81.250% (39 of 48)
# Class snowy:
#     Sensitivity (TPR):  30.000% (3 of 10)
#     Specificity (TNR):  77.500% (31 of 40)
#     Precision:          25.000% (3 of 12)
#     Neg. pred. value:   81.579% (31 of 38)
# Class rainy:
#     Sensitivity (TPR):  40.000% (4 of 10)
#     Specificity (TNR):  85.000% (34 of 40)
#     Precision:          40.000% (4 of 10)
#     Neg. pred. value:   85.000% (34 of 40)
#
# Overall accuracy:   26.000% (13 of 50)
# Balanced accuracy:  26.000%
# array([[4, 2, 0, 2, 2],
#        [2, 1, 1, 4, 2],
#        [6, 1, 1, 1, 1],
#        [4, 2, 0, 3, 1],
#        [3, 1, 0, 2, 4]], dtype=int64)
