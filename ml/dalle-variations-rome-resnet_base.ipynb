# %%
import imp
import os
import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
import glob
import cv2
import PIL
import matplotlib.pyplot as plt
from pyMLaux.functions import evaluate_classification_result, plot_history

# %% [markdown]
# # DALLE variations datasets and rome base base line: Resnet Base
# Check for GPU

# %%
tf.get_logger().setLevel('ERROR')

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# Basic constants

# %%
data_dir = "./../data/rome-dalle-variation"
data_dir_test = "./../data/rome-validation"
batch_size = 16
number_images = 50
image_height = 224
image_width = 224
nr_color_channels = 3
seed = 2023

# %% [markdown]
# Create ImageDataGenerator for data augmentation of training data

# %%
datagen = keras.preprocessing.image.ImageDataGenerator(rescale=(1. / 255),
                                   shear_range=0.1,
                                   zoom_range=0.1,
                                   rotation_range=10,
                                   preprocessing_function=keras.applications.resnet50.preprocess_input,
                                   horizontal_flip=True,
                                   fill_mode='constant',
                                   cval=0)

# %% [markdown]
# Get training data

# %%
img_train = datagen.flow_from_directory(data_dir, target_size=(image_width,image_height), 
                                                    batch_size=batch_size, seed=seed,
                                                    class_mode='categorical')
img_train
# Out:
# Found 1405 images belonging to 5 classes.

# %% [markdown]
# Get test data

# %%
img_test = datagen.flow_from_directory(data_dir_test, target_size=(image_width,image_height), 
                                                    batch_size=batch_size, seed=seed,
                                                    class_mode='categorical')
img_test
# Out:
# Found 50 images belonging to 5 classes.

# %% [markdown]
# Load ResNet50
#
# (approach taken from: https://medium.com/@kenneth.ca95/a-guide-to-transfer-learning-with-keras-using-resnet50-a81a4a28084b)

# %%
input_tensor = keras.Input(shape=(image_height,image_width,nr_color_channels))
resnet50_model = keras.applications.ResNet50(include_top=False,weights="imagenet",input_tensor=input_tensor)

# %%
for layer in resnet50_model.layers[:134]:
    layer.trainable = False

# %%
model = keras.models.Sequential()
model.add(resnet50_model)
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(5,activation='softmax'))

# %% [markdown]
# Create model checkpoints

# %%
filepath = "./" + 'models/dalle_variation_rome_resnet_base/dalle_variation_rome_resnet_base_{epoch:02d}-{val_accuracy:.4f}.hdf5'
check_point = tf.keras.callbacks.ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,
                                                save_best_only=True, mode='max')

# %%
callbacks_list = [check_point]

# %%
model.compile(loss='categorical_crossentropy',
                  optimizer=keras.optimizers.RMSprop(learning_rate=2e-5),
                  metrics=['accuracy'])

# %%
history = model.fit(img_train,
                    steps_per_epoch=((len(img_train.filenames)) // batch_size), 
                    epochs=25,
                    validation_data=img_test, 
                    validation_steps=(len(img_test.filenames) // batch_size),
                    callbacks=callbacks_list)
# Out:
# Epoch 1/25
# 87/87 [==============================] - 29s 215ms/step - loss: 1.6987 - accuracy: 0.4953 - val_loss: 1.9713 - val_accuracy: 0.1458
#
# Epoch 00001: val_accuracy improved from -inf to 0.14583, saving model to ./models/dalle_variation_rome_resnet_base\dalle_variation_rome_resnet_base_01-0.1458.hdf5
# c:\Users\selin\miniconda3\envs\cov-project\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 2/25
# 87/87 [==============================] - 13s 146ms/step - loss: 1.1452 - accuracy: 0.6271 - val_loss: 2.1376 - val_accuracy: 0.2292
#
# Epoch 00002: val_accuracy improved from 0.14583 to 0.22917, saving model to ./models/dalle_variation_rome_resnet_base\dalle_variation_rome_resnet_base_02-0.2292.hdf5
# Epoch 3/25
# 87/87 [==============================] - 13s 146ms/step - loss: 0.9929 - accuracy: 0.6609 - val_loss: 1.9751 - val_accuracy: 0.3750
#
# Epoch 00003: val_accuracy improved from 0.22917 to 0.37500, saving model to ./models/dalle_variation_rome_resnet_base\dalle_variation_rome_resnet_base_03-0.3750.hdf5
# Epoch 4/25
# 87/87 [==============================] - 13s 145ms/step - loss: 0.8452 - accuracy: 0.7027 - val_loss: 1.7674 - val_accuracy: 0.4375
#
# Epoch 00004: val_accuracy improved from 0.37500 to 0.43750, saving model to ./models/dalle_variation_rome_resnet_base\dalle_variation_rome_resnet_base_04-0.4375.hdf5
# Epoch 5/25
# 87/87 [==============================] - 13s 154ms/step - loss: 0.8681 - accuracy: 0.7048 - val_loss: 1.6603 - val_accuracy: 0.4375
#
# Epoch 00005: val_accuracy did not improve from 0.43750
# Epoch 6/25
# 87/87 [==============================] - 13s 152ms/step - loss: 0.7293 - accuracy: 0.7487 - val_loss: 1.4796 - val_accuracy: 0.5625
#
# Epoch 00006: val_accuracy improved from 0.43750 to 0.56250, saving model to ./models/dalle_variation_rome_resnet_base\dalle_variation_rome_resnet_base_06-0.5625.hdf5
# Epoch 7/25
# 87/87 [==============================] - 13s 155ms/step - loss: 0.6487 - accuracy: 0.7804 - val_loss: 2.3382 - val_accuracy: 0.5208
#
# Epoch 00007: val_accuracy did not improve from 0.56250
# Epoch 8/25
# 87/87 [==============================] - 13s 151ms/step - loss: 0.6104 - accuracy: 0.7847 - val_loss: 2.0560 - val_accuracy: 0.5417
#
# Epoch 00008: val_accuracy did not improve from 0.56250
# Epoch 9/25
# 87/87 [==============================] - 14s 155ms/step - loss: 0.5773 - accuracy: 0.7898 - val_loss: 1.3553 - val_accuracy: 0.6458
#
# Epoch 00009: val_accuracy improved from 0.56250 to 0.64583, saving model to ./models/dalle_variation_rome_resnet_base\dalle_variation_rome_resnet_base_09-0.6458.hdf5
# Epoch 10/25
# 87/87 [==============================] - 14s 162ms/step - loss: 0.5302 - accuracy: 0.8150 - val_loss: 1.7701 - val_accuracy: 0.5208
#
# Epoch 00010: val_accuracy did not improve from 0.64583
# Epoch 11/25
# 87/87 [==============================] - 13s 146ms/step - loss: 0.4846 - accuracy: 0.8351 - val_loss: 1.6243 - val_accuracy: 0.5833
#
# Epoch 00011: val_accuracy did not improve from 0.64583
# Epoch 12/25
# 87/87 [==============================] - 14s 159ms/step - loss: 0.5136 - accuracy: 0.8236 - val_loss: 1.4504 - val_accuracy: 0.6042
#
# Epoch 00012: val_accuracy did not improve from 0.64583
# Epoch 13/25
# 87/87 [==============================] - 13s 153ms/step - loss: 0.4678 - accuracy: 0.8481 - val_loss: 2.3180 - val_accuracy: 0.6458
#
# Epoch 00013: val_accuracy did not improve from 0.64583
# Epoch 14/25
# 87/87 [==============================] - 13s 152ms/step - loss: 0.4207 - accuracy: 0.8517 - val_loss: 1.7802 - val_accuracy: 0.6042
#
# Epoch 00014: val_accuracy did not improve from 0.64583
# Epoch 15/25
# 87/87 [==============================] - 13s 149ms/step - loss: 0.3722 - accuracy: 0.8740 - val_loss: 1.4137 - val_accuracy: 0.6458
#
# Epoch 00015: val_accuracy did not improve from 0.64583
# Epoch 16/25
# 87/87 [==============================] - 13s 146ms/step - loss: 0.3670 - accuracy: 0.8747 - val_loss: 3.1778 - val_accuracy: 0.4167
#
# Epoch 00016: val_accuracy did not improve from 0.64583
# Epoch 17/25
# 87/87 [==============================] - 13s 148ms/step - loss: 0.3667 - accuracy: 0.8675 - val_loss: 1.8999 - val_accuracy: 0.4792
#
# Epoch 00017: val_accuracy did not improve from 0.64583
# Epoch 18/25
# 87/87 [==============================] - 13s 147ms/step - loss: 0.3540 - accuracy: 0.8740 - val_loss: 1.5674 - val_accuracy: 0.5625
#
# Epoch 00018: val_accuracy did not improve from 0.64583
# Epoch 19/25
# 87/87 [==============================] - 13s 148ms/step - loss: 0.2849 - accuracy: 0.8906 - val_loss: 1.4103 - val_accuracy: 0.6042
#
# Epoch 00019: val_accuracy did not improve from 0.64583
# Epoch 20/25
# 87/87 [==============================] - 13s 147ms/step - loss: 0.2962 - accuracy: 0.8913 - val_loss: 2.5389 - val_accuracy: 0.4792
#
# Epoch 00020: val_accuracy did not improve from 0.64583
# Epoch 21/25
# 87/87 [==============================] - 13s 148ms/step - loss: 0.2592 - accuracy: 0.9042 - val_loss: 1.6002 - val_accuracy: 0.6042
#
# Epoch 00021: val_accuracy did not improve from 0.64583
# Epoch 22/25
# 87/87 [==============================] - 13s 147ms/step - loss: 0.2614 - accuracy: 0.9100 - val_loss: 2.2706 - val_accuracy: 0.6250
#
# Epoch 00022: val_accuracy did not improve from 0.64583
# Epoch 23/25
# 87/87 [==============================] - 13s 148ms/step - loss: 0.2808 - accuracy: 0.9021 - val_loss: 2.1549 - val_accuracy: 0.6250
#
# Epoch 00023: val_accuracy did not improve from 0.64583
# Epoch 24/25
# 87/87 [==============================] - 13s 148ms/step - loss: 0.2458 - accuracy: 0.9114 - val_loss: 2.0036 - val_accuracy: 0.5625
#
# Epoch 00024: val_accuracy did not improve from 0.64583
# Epoch 25/25
# 87/87 [==============================] - 13s 150ms/step - loss: 0.2689 - accuracy: 0.9021 - val_loss: 2.3757 - val_accuracy: 0.6042
#
# Epoch 00025: val_accuracy did not improve from 0.64583

# %% [markdown]
# Evaluate model

# %%
plot_history(history)

# %% [markdown]
# Load best model

# %%
model = keras.models.load_model("./models/dalle_variation_rome_resnet_base/dalle_variation_rome_resnet_base_09-0.6458.hdf5")
pred = model.predict(img_test, steps=len(img_test.filenames))

# %%
keras.utils.plot_model(model)

# %%
evaluate_classification_result(img_test.classes, pred,classes=["foggy","cloudy","sunny","snowy","rainy"])
# Out:
# [[3 2 0 3 2]
#  [1 1 3 3 2]
#  [3 1 4 0 2]
#  [1 2 3 3 1]
#  [2 2 4 2 0]]
#
#
# Class foggy:
#     Sensitivity (TPR):  30.000% (3 of 10)
#     Specificity (TNR):  82.500% (33 of 40)
#     Precision:          30.000% (3 of 10)
#     Neg. pred. value:   82.500% (33 of 40)
# Class cloudy:
#     Sensitivity (TPR):  10.000% (1 of 10)
#     Specificity (TNR):  82.500% (33 of 40)
#     Precision:          12.500% (1 of 8)
#     Neg. pred. value:   78.571% (33 of 42)
# Class sunny:
#     Sensitivity (TPR):  40.000% (4 of 10)
#     Specificity (TNR):  75.000% (30 of 40)
#     Precision:          28.571% (4 of 14)
#     Neg. pred. value:   83.333% (30 of 36)
# Class snowy:
#     Sensitivity (TPR):  30.000% (3 of 10)
#     Specificity (TNR):  80.000% (32 of 40)
#     Precision:          27.273% (3 of 11)
#     Neg. pred. value:   82.051% (32 of 39)
# Class rainy:
#     Sensitivity (TPR):   0.000% (0 of 10)
#     Specificity (TNR):  82.500% (33 of 40)
#     Precision:           0.000% (0 of 7)
#     Neg. pred. value:   76.744% (33 of 43)
#
# Overall accuracy:   22.000% (11 of 50)
# Balanced accuracy:  22.000%
# array([[3, 2, 0, 3, 2],
#        [1, 1, 3, 3, 2],
#        [3, 1, 4, 0, 2],
#        [1, 2, 3, 3, 1],
#        [2, 2, 4, 2, 0]], dtype=int64)
