# %%
import imp
import os
import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
import glob
import cv2
import PIL
import matplotlib.pyplot as plt
from pyMLaux.functions import evaluate_classification_result, plot_history

# %% [markdown]
# # Kaggle croped dataset base line: Custom CNN model
# Check for GPU

# %%
tf.get_logger().setLevel('ERROR')

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# Basic constants

# %%
data_dir = "./../data/kaggle-5-class-weather-dataset-cropped"
batch_size = 16
number_images = 50
image_height = 224
image_width = 224
nr_color_channels = 3
seed = 2023

# %% [markdown]
# Create ImageDataGenerator for data augmentation of training data

# %%
datagen = keras.preprocessing.image.ImageDataGenerator(rescale=(1. / 255),
                                   shear_range=0.1,
                                   zoom_range=0.1,
                                   rotation_range=10,
                                   horizontal_flip=True,
                                   fill_mode='constant',
                                   validation_split= 0.2,
                                   cval=0)

# %% [markdown]
# Get training data

# %%
img_train = datagen.flow_from_directory(data_dir, target_size=(image_width,image_height), 
                                                    batch_size=batch_size,  subset='training', seed=seed,
                                                    class_mode='categorical')
img_train
# Out:
# Found 200 images belonging to 5 classes.

# %% [markdown]
# Get test data

# %%
img_test = datagen.flow_from_directory(data_dir, target_size=(image_width,image_height), 
                                                    batch_size=batch_size,  subset='validation', seed=seed,
                                                    class_mode='categorical')
img_test
# Out:
# Found 50 images belonging to 5 classes.

# %% [markdown]
# Build model
#
# model architecture based on: https://www.kaggle.com/code/tejaswi2003/20bd1a6637-weather-classification-cnn

# %%
model = tf.keras.models.Sequential()
model.add(keras.layers.Conv2D(32,activation="relu",kernel_size=3,input_shape=(image_width, image_height, 3)))
model.add(keras.layers.MaxPooling2D((2,2),padding='same'))
model.add(keras.layers.Conv2D(64,activation="relu",kernel_size=3))
model.add(keras.layers.MaxPooling2D((2,2),padding='same'))
model.add(keras.layers.Conv2D(128,activation="relu",kernel_size=3))
model.add(keras.layers.MaxPooling2D((2,2),padding='same'))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(100,activation="relu"))
model.add(keras.layers.Dense(5,activation="softmax"))

# %% [markdown]
# Create model checkpoints

# %%
filepath = "./" + 'models/cropped_custom/cropped_custom_{epoch:02d}-{val_accuracy:.4f}.hdf5'
check_point = tf.keras.callbacks.ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,
                                                save_best_only=True, mode='max')

# %%
callbacks_list = [check_point]

# %%
model.compile(loss='categorical_crossentropy',
                  optimizer=keras.optimizers.RMSprop(learning_rate=2e-5),
                  metrics=['accuracy'])

# %%
history = model.fit(img_train,
                    steps_per_epoch=(len(img_train.filenames) // batch_size), 
                    epochs=25,
                    validation_data=img_test, 
                    validation_steps=(len(img_test.filenames) // batch_size),
                    callbacks=callbacks_list)
# Out:
# Epoch 1/25
# 12/12 [==============================] - 3s 196ms/step - loss: 1.6518 - accuracy: 0.1630 - val_loss: 1.5898 - val_accuracy: 0.2500
#
# Epoch 00001: val_accuracy improved from -inf to 0.25000, saving model to ./models/cropped_custom\cropped_custom_01-0.2500.hdf5
# Epoch 2/25
# 12/12 [==============================] - 3s 255ms/step - loss: 1.6051 - accuracy: 0.2011 - val_loss: 1.5721 - val_accuracy: 0.2292
#
# Epoch 00002: val_accuracy did not improve from 0.25000
# Epoch 3/25
# 12/12 [==============================] - 3s 277ms/step - loss: 1.5746 - accuracy: 0.2935 - val_loss: 1.5477 - val_accuracy: 0.2083
#
# Epoch 00003: val_accuracy did not improve from 0.25000
# Epoch 4/25
# 12/12 [==============================] - 3s 203ms/step - loss: 1.5463 - accuracy: 0.3641 - val_loss: 1.5193 - val_accuracy: 0.3750
#
# Epoch 00004: val_accuracy improved from 0.25000 to 0.37500, saving model to ./models/cropped_custom\cropped_custom_04-0.3750.hdf5
# Epoch 5/25
# 12/12 [==============================] - 3s 234ms/step - loss: 1.5204 - accuracy: 0.4293 - val_loss: 1.5044 - val_accuracy: 0.4792
#
# Epoch 00005: val_accuracy improved from 0.37500 to 0.47917, saving model to ./models/cropped_custom\cropped_custom_05-0.4792.hdf5
# Epoch 6/25
# 12/12 [==============================] - 2s 180ms/step - loss: 1.4976 - accuracy: 0.4022 - val_loss: 1.4739 - val_accuracy: 0.4375
#
# Epoch 00006: val_accuracy did not improve from 0.47917
# Epoch 7/25
# 12/12 [==============================] - 2s 181ms/step - loss: 1.4494 - accuracy: 0.4728 - val_loss: 1.4469 - val_accuracy: 0.4167
#
# Epoch 00007: val_accuracy did not improve from 0.47917
# Epoch 8/25
# 12/12 [==============================] - 2s 181ms/step - loss: 1.4209 - accuracy: 0.4674 - val_loss: 1.4146 - val_accuracy: 0.4792
#
# Epoch 00008: val_accuracy did not improve from 0.47917
# Epoch 9/25
# 12/12 [==============================] - 2s 180ms/step - loss: 1.3825 - accuracy: 0.5163 - val_loss: 1.4114 - val_accuracy: 0.4792
#
# Epoch 00009: val_accuracy did not improve from 0.47917
# Epoch 10/25
# 12/12 [==============================] - 2s 180ms/step - loss: 1.3574 - accuracy: 0.4891 - val_loss: 1.3891 - val_accuracy: 0.5000
#
# Epoch 00010: val_accuracy improved from 0.47917 to 0.50000, saving model to ./models/cropped_custom\cropped_custom_10-0.5000.hdf5
# Epoch 11/25
# 12/12 [==============================] - 2s 181ms/step - loss: 1.3310 - accuracy: 0.5163 - val_loss: 1.3249 - val_accuracy: 0.5000
#
# Epoch 00011: val_accuracy did not improve from 0.50000
# Epoch 12/25
# 12/12 [==============================] - 2s 179ms/step - loss: 1.2849 - accuracy: 0.5870 - val_loss: 1.3522 - val_accuracy: 0.3958
#
# Epoch 00012: val_accuracy did not improve from 0.50000
# Epoch 13/25
# 12/12 [==============================] - 2s 187ms/step - loss: 1.2886 - accuracy: 0.5380 - val_loss: 1.3205 - val_accuracy: 0.4167
#
# Epoch 00013: val_accuracy did not improve from 0.50000
# Epoch 14/25
# 12/12 [==============================] - 2s 179ms/step - loss: 1.2550 - accuracy: 0.5380 - val_loss: 1.3381 - val_accuracy: 0.4375
#
# Epoch 00014: val_accuracy did not improve from 0.50000
# Epoch 15/25
# 12/12 [==============================] - 2s 181ms/step - loss: 1.2290 - accuracy: 0.5598 - val_loss: 1.2929 - val_accuracy: 0.5208
#
# Epoch 00015: val_accuracy improved from 0.50000 to 0.52083, saving model to ./models/cropped_custom\cropped_custom_15-0.5208.hdf5
# Epoch 16/25
# 12/12 [==============================] - 2s 188ms/step - loss: 1.2041 - accuracy: 0.5924 - val_loss: 1.3392 - val_accuracy: 0.4167
#
# Epoch 00016: val_accuracy did not improve from 0.52083
# Epoch 17/25
# 12/12 [==============================] - 2s 177ms/step - loss: 1.1681 - accuracy: 0.5924 - val_loss: 1.3191 - val_accuracy: 0.4792
#
# Epoch 00017: val_accuracy did not improve from 0.52083
# Epoch 18/25
# 12/12 [==============================] - 2s 180ms/step - loss: 1.1349 - accuracy: 0.6141 - val_loss: 1.3203 - val_accuracy: 0.4167
#
# Epoch 00018: val_accuracy did not improve from 0.52083
# Epoch 19/25
# 12/12 [==============================] - 2s 176ms/step - loss: 1.1538 - accuracy: 0.5924 - val_loss: 1.3287 - val_accuracy: 0.4375
#
# Epoch 00019: val_accuracy did not improve from 0.52083
# Epoch 20/25
# 12/12 [==============================] - 2s 177ms/step - loss: 1.1231 - accuracy: 0.5489 - val_loss: 1.3948 - val_accuracy: 0.4583
#
# Epoch 00020: val_accuracy did not improve from 0.52083
# Epoch 21/25
# 12/12 [==============================] - 2s 178ms/step - loss: 1.1183 - accuracy: 0.6141 - val_loss: 1.3132 - val_accuracy: 0.5000
#
# Epoch 00021: val_accuracy did not improve from 0.52083
# Epoch 22/25
# 12/12 [==============================] - 2s 180ms/step - loss: 1.0838 - accuracy: 0.6196 - val_loss: 1.3342 - val_accuracy: 0.3958
#
# Epoch 00022: val_accuracy did not improve from 0.52083
# Epoch 23/25
# 12/12 [==============================] - 2s 180ms/step - loss: 1.0802 - accuracy: 0.5924 - val_loss: 1.2711 - val_accuracy: 0.5000
#
# Epoch 00023: val_accuracy did not improve from 0.52083
# Epoch 24/25
# 12/12 [==============================] - 2s 182ms/step - loss: 1.0654 - accuracy: 0.5870 - val_loss: 1.2974 - val_accuracy: 0.4167
#
# Epoch 00024: val_accuracy did not improve from 0.52083
# Epoch 25/25
# 12/12 [==============================] - 2s 185ms/step - loss: 1.0772 - accuracy: 0.5815 - val_loss: 1.3752 - val_accuracy: 0.3958
#
# Epoch 00025: val_accuracy did not improve from 0.52083

# %% [markdown]
# Evaluate model

# %%
plot_history(history)

# %% [markdown]
# Load best model

# %%
model = keras.models.load_model("./models/big_custom/big_custom_20-0.7062.hdf5")
pred = model.predict(img_test, steps=len(img_test.filenames))

# %%
keras.utils.plot_model(model)

# %%
evaluate_classification_result(img_test.classes, pred,classes=["foggy","cloudy","sunny","snowy","rainy"])
# Out:
# [[4 1 0 3 2]
#  [3 1 1 2 3]
#  [5 2 1 0 2]
#  [3 1 2 1 3]
#  [4 2 0 1 3]]
#
#
# Class foggy:
#     Sensitivity (TPR):  40.000% (4 of 10)
#     Specificity (TNR):  62.500% (25 of 40)
#     Precision:          21.053% (4 of 19)
#     Neg. pred. value:   80.645% (25 of 31)
# Class cloudy:
#     Sensitivity (TPR):  10.000% (1 of 10)
#     Specificity (TNR):  85.000% (34 of 40)
#     Precision:          14.286% (1 of 7)
#     Neg. pred. value:   79.070% (34 of 43)
# Class sunny:
#     Sensitivity (TPR):  10.000% (1 of 10)
#     Specificity (TNR):  92.500% (37 of 40)
#     Precision:          25.000% (1 of 4)
#     Neg. pred. value:   80.435% (37 of 46)
# Class snowy:
#     Sensitivity (TPR):  10.000% (1 of 10)
#     Specificity (TNR):  85.000% (34 of 40)
#     Precision:          14.286% (1 of 7)
#     Neg. pred. value:   79.070% (34 of 43)
# Class rainy:
#     Sensitivity (TPR):  30.000% (3 of 10)
#     Specificity (TNR):  75.000% (30 of 40)
#     Precision:          23.077% (3 of 13)
#     Neg. pred. value:   81.081% (30 of 37)
#
# Overall accuracy:   20.000% (10 of 50)
# Balanced accuracy:  20.000%
# array([[4, 1, 0, 3, 2],
#        [3, 1, 1, 2, 3],
#        [5, 2, 1, 0, 2],
#        [3, 1, 2, 1, 3],
#        [4, 2, 0, 1, 3]], dtype=int64)
