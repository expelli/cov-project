# %%
import imp
import os
import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
import glob
import cv2
import PIL
import matplotlib.pyplot as plt
from pyMLaux.functions import evaluate_classification_result, plot_history

# %% [markdown]
# # DALLE prompted dataset base line: Resnet Base
# Check for GPU

# %%
tf.get_logger().setLevel('ERROR')

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# Basic constants

# %%
data_dir = "./../data/dalle-prompted-resized"
data_dir_test = "./../data/rome-validation"
batch_size = 16
number_images = 50
image_height = 224
image_width = 224
nr_color_channels = 3
seed = 2023

# %% [markdown]
# Create ImageDataGenerator for data augmentation of training data

# %%
datagen = keras.preprocessing.image.ImageDataGenerator(rescale=(1. / 255),
                                   shear_range=0.1,
                                   zoom_range=0.1,
                                   rotation_range=10,
                                   preprocessing_function=keras.applications.resnet50.preprocess_input,
                                   horizontal_flip=True,
                                   fill_mode='constant',
                                   cval=0)

# %% [markdown]
# Get training data

# %%
img_train = datagen.flow_from_directory(data_dir, target_size=(image_width,image_height), 
                                                    batch_size=batch_size, seed=seed,
                                                    class_mode='categorical')
img_train
# Out:
# Found 1598 images belonging to 5 classes.

# %% [markdown]
# Get test data

# %%
img_test = datagen.flow_from_directory(data_dir_test, target_size=(image_width,image_height), 
                                                    batch_size=batch_size, seed=seed,
                                                    class_mode='categorical')
img_test
# Out:
# Found 50 images belonging to 5 classes.

# %% [markdown]
# Load ResNet50
#
# (approach taken from: https://medium.com/@kenneth.ca95/a-guide-to-transfer-learning-with-keras-using-resnet50-a81a4a28084b)

# %%
input_tensor = keras.Input(shape=(image_height,image_width,nr_color_channels))
resnet50_model = keras.applications.ResNet50(include_top=False,weights="imagenet",input_tensor=input_tensor)

# %%
for layer in resnet50_model.layers[:134]:
    layer.trainable = False

# %%
model = keras.models.Sequential()
model.add(resnet50_model)
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(5,activation='softmax'))

# %% [markdown]
# Create model checkpoints

# %%
filepath = "./" + 'models/dalle_prompt_resnet_base/dalle_prompt_resnet_base_{epoch:02d}-{val_accuracy:.4f}.hdf5'
check_point = tf.keras.callbacks.ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,
                                                save_best_only=True, mode='max')

# %%
callbacks_list = [check_point]

# %%
model.compile(loss='categorical_crossentropy',
                  optimizer=keras.optimizers.RMSprop(learning_rate=2e-5),
                  metrics=['accuracy'])

# %%
history = model.fit(img_train,
                    steps_per_epoch=((len(img_train.filenames)) // batch_size), 
                    epochs=25,
                    validation_data=img_test, 
                    validation_steps=(len(img_test.filenames) // batch_size),
                    callbacks=callbacks_list)
# Out:
# Epoch 1/25
# 99/99 [==============================] - 26s 176ms/step - loss: 2.3296 - accuracy: 0.3818 - val_loss: 2.1194 - val_accuracy: 0.2083
#
# Epoch 00001: val_accuracy improved from -inf to 0.20833, saving model to ./models/dalle_prompt_resnet_base\dalle_prompt_resnet_base_01-0.2083.hdf5
# c:\Users\selin\miniconda3\envs\cov-project\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 2/25
# 99/99 [==============================] - 15s 146ms/step - loss: 1.8392 - accuracy: 0.4539 - val_loss: 2.5548 - val_accuracy: 0.2917
#
# Epoch 00002: val_accuracy improved from 0.20833 to 0.29167, saving model to ./models/dalle_prompt_resnet_base\dalle_prompt_resnet_base_02-0.2917.hdf5
# Epoch 3/25
# 99/99 [==============================] - 15s 150ms/step - loss: 1.5688 - accuracy: 0.5076 - val_loss: 1.6619 - val_accuracy: 0.3750
#
# Epoch 00003: val_accuracy improved from 0.29167 to 0.37500, saving model to ./models/dalle_prompt_resnet_base\dalle_prompt_resnet_base_03-0.3750.hdf5
# Epoch 4/25
# 99/99 [==============================] - 14s 146ms/step - loss: 1.5652 - accuracy: 0.4848 - val_loss: 1.8526 - val_accuracy: 0.5417
#
# Epoch 00004: val_accuracy improved from 0.37500 to 0.54167, saving model to ./models/dalle_prompt_resnet_base\dalle_prompt_resnet_base_04-0.5417.hdf5
# Epoch 5/25
# 99/99 [==============================] - 15s 146ms/step - loss: 1.4043 - accuracy: 0.5341 - val_loss: 1.8633 - val_accuracy: 0.5208
#
# Epoch 00005: val_accuracy did not improve from 0.54167
# Epoch 6/25
# 99/99 [==============================] - 15s 147ms/step - loss: 1.3235 - accuracy: 0.5518 - val_loss: 1.6254 - val_accuracy: 0.6042
#
# Epoch 00006: val_accuracy improved from 0.54167 to 0.60417, saving model to ./models/dalle_prompt_resnet_base\dalle_prompt_resnet_base_06-0.6042.hdf5
# Epoch 7/25
# 99/99 [==============================] - 15s 147ms/step - loss: 1.2918 - accuracy: 0.5569 - val_loss: 1.5532 - val_accuracy: 0.6042
#
# Epoch 00007: val_accuracy did not improve from 0.60417
# Epoch 8/25
# 99/99 [==============================] - 15s 147ms/step - loss: 1.1961 - accuracy: 0.5841 - val_loss: 2.1440 - val_accuracy: 0.4792
#
# Epoch 00008: val_accuracy did not improve from 0.60417
# Epoch 9/25
# 99/99 [==============================] - 14s 145ms/step - loss: 1.1377 - accuracy: 0.6182 - val_loss: 2.9546 - val_accuracy: 0.4375
#
# Epoch 00009: val_accuracy did not improve from 0.60417
# Epoch 10/25
# 99/99 [==============================] - 15s 149ms/step - loss: 1.1165 - accuracy: 0.6037 - val_loss: 2.6266 - val_accuracy: 0.4375
#
# Epoch 00010: val_accuracy did not improve from 0.60417
# Epoch 11/25
# 99/99 [==============================] - 15s 146ms/step - loss: 0.9947 - accuracy: 0.6378 - val_loss: 3.1979 - val_accuracy: 0.5000
#
# Epoch 00011: val_accuracy did not improve from 0.60417
# Epoch 12/25
# 99/99 [==============================] - 15s 147ms/step - loss: 0.9872 - accuracy: 0.6479 - val_loss: 1.6049 - val_accuracy: 0.5000
#
# Epoch 00012: val_accuracy did not improve from 0.60417
# Epoch 13/25
# 99/99 [==============================] - 14s 145ms/step - loss: 0.9700 - accuracy: 0.6517 - val_loss: 2.4107 - val_accuracy: 0.5208
#
# Epoch 00013: val_accuracy did not improve from 0.60417
# Epoch 14/25
# 99/99 [==============================] - 15s 150ms/step - loss: 0.9279 - accuracy: 0.6789 - val_loss: 1.8755 - val_accuracy: 0.5625
#
# Epoch 00014: val_accuracy did not improve from 0.60417
# Epoch 15/25
# 99/99 [==============================] - 15s 147ms/step - loss: 0.9236 - accuracy: 0.6669 - val_loss: 4.7691 - val_accuracy: 0.3333
#
# Epoch 00015: val_accuracy did not improve from 0.60417
# Epoch 16/25
# 99/99 [==============================] - 15s 149ms/step - loss: 0.8579 - accuracy: 0.6776 - val_loss: 2.3930 - val_accuracy: 0.4792
#
# Epoch 00016: val_accuracy did not improve from 0.60417
# Epoch 17/25
# 99/99 [==============================] - 14s 146ms/step - loss: 0.8703 - accuracy: 0.6814 - val_loss: 2.8515 - val_accuracy: 0.5000
#
# Epoch 00017: val_accuracy did not improve from 0.60417
# Epoch 18/25
# 99/99 [==============================] - 16s 158ms/step - loss: 0.8588 - accuracy: 0.6839 - val_loss: 2.3149 - val_accuracy: 0.5000
#
# Epoch 00018: val_accuracy did not improve from 0.60417
# Epoch 19/25
# 99/99 [==============================] - 16s 156ms/step - loss: 0.8496 - accuracy: 0.6852 - val_loss: 2.9049 - val_accuracy: 0.5417
#
# Epoch 00019: val_accuracy did not improve from 0.60417
# Epoch 20/25
# 99/99 [==============================] - 15s 148ms/step - loss: 0.8112 - accuracy: 0.7029 - val_loss: 2.6777 - val_accuracy: 0.4792
#
# Epoch 00020: val_accuracy did not improve from 0.60417
# Epoch 21/25
# 99/99 [==============================] - 14s 145ms/step - loss: 0.8008 - accuracy: 0.7111 - val_loss: 3.1377 - val_accuracy: 0.4375
#
# Epoch 00021: val_accuracy did not improve from 0.60417
# Epoch 22/25
# 99/99 [==============================] - 15s 153ms/step - loss: 0.7509 - accuracy: 0.7193 - val_loss: 3.0048 - val_accuracy: 0.3958
#
# Epoch 00022: val_accuracy did not improve from 0.60417
# Epoch 23/25
# 99/99 [==============================] - 15s 149ms/step - loss: 0.7150 - accuracy: 0.7269 - val_loss: 2.3902 - val_accuracy: 0.5625
#
# Epoch 00023: val_accuracy did not improve from 0.60417
# Epoch 24/25
# 99/99 [==============================] - 15s 148ms/step - loss: 0.7265 - accuracy: 0.7269 - val_loss: 3.7870 - val_accuracy: 0.3542
#
# Epoch 00024: val_accuracy did not improve from 0.60417
# Epoch 25/25
# 99/99 [==============================] - 15s 154ms/step - loss: 0.7353 - accuracy: 0.7257 - val_loss: 2.1516 - val_accuracy: 0.5417
#
# Epoch 00025: val_accuracy did not improve from 0.60417

# %% [markdown]
# Evaluate model

# %%
plot_history(history)

# %% [markdown]
# Load best model

# %%
model = keras.models.load_model("./models/dalle_prompt_resnet_base/dalle_prompt_resnet_base_06-0.6042.hdf5")
pred = model.predict(img_test, steps=len(img_test.filenames))

# %%
keras.utils.plot_model(model)

# %%
evaluate_classification_result(img_test.classes, pred,classes=["foggy","cloudy","sunny","snowy","rainy"])
# Out:
# [[2 0 0 5 3]
#  [1 0 3 5 1]
#  [1 1 2 5 1]
#  [1 1 0 5 3]
#  [1 0 2 4 3]]
#
#
# Class foggy:
#     Sensitivity (TPR):  20.000% (2 of 10)
#     Specificity (TNR):  90.000% (36 of 40)
#     Precision:          33.333% (2 of 6)
#     Neg. pred. value:   81.818% (36 of 44)
# Class cloudy:
#     Sensitivity (TPR):   0.000% (0 of 10)
#     Specificity (TNR):  95.000% (38 of 40)
#     Precision:           0.000% (0 of 2)
#     Neg. pred. value:   79.167% (38 of 48)
# Class sunny:
#     Sensitivity (TPR):  20.000% (2 of 10)
#     Specificity (TNR):  87.500% (35 of 40)
#     Precision:          28.571% (2 of 7)
#     Neg. pred. value:   81.395% (35 of 43)
# Class snowy:
#     Sensitivity (TPR):  50.000% (5 of 10)
#     Specificity (TNR):  52.500% (21 of 40)
#     Precision:          20.833% (5 of 24)
#     Neg. pred. value:   80.769% (21 of 26)
# Class rainy:
#     Sensitivity (TPR):  30.000% (3 of 10)
#     Specificity (TNR):  80.000% (32 of 40)
#     Precision:          27.273% (3 of 11)
#     Neg. pred. value:   82.051% (32 of 39)
#
# Overall accuracy:   24.000% (12 of 50)
# Balanced accuracy:  24.000%
# array([[2, 0, 0, 5, 3],
#        [1, 0, 3, 5, 1],
#        [1, 1, 2, 5, 1],
#        [1, 1, 0, 5, 3],
#        [1, 0, 2, 4, 3]], dtype=int64)
