# %%
import imp
import os
import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
import glob
import cv2
import PIL
import matplotlib.pyplot as plt
from pyMLaux.functions import evaluate_classification_result, plot_history

# %% [markdown]
# # DALLE variations dataset and rome base line: custom cnn model
# Check for GPU

# %%
tf.get_logger().setLevel('ERROR')

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# Basic constants

# %%
data_dir = "./../data/rome-dalle-variation"
data_dir_test = "./../data/rome-validation"
batch_size = 16
number_images = 50
image_height = 224
image_width = 224
nr_color_channels = 3
seed = 2023

# %% [markdown]
# Create ImageDataGenerator for data augmentation of training data

# %%
datagen = keras.preprocessing.image.ImageDataGenerator(rescale=(1. / 255),
                                   shear_range=0.1,
                                   zoom_range=0.1,
                                   rotation_range=10,
                                   horizontal_flip=True,
                                   fill_mode='constant',
                                   cval=0)

# %% [markdown]
# Get training data

# %%
img_train = datagen.flow_from_directory(data_dir, target_size=(image_width,image_height), 
                                                    batch_size=batch_size, seed=seed,
                                                    class_mode='categorical')
img_train
# Out:
# Found 1426 images belonging to 5 classes.

# %% [markdown]
# Get test data

# %%
img_test = datagen.flow_from_directory(data_dir_test, target_size=(image_width,image_height), 
                                                    batch_size=batch_size, seed=seed,
                                                    class_mode='categorical')
img_test
# Out:
# Found 50 images belonging to 5 classes.

# %% [markdown]
# Build model
#
# model architecture based on: https://www.kaggle.com/code/tejaswi2003/20bd1a6637-weather-classification-cnn

# %%
model = tf.keras.models.Sequential()
model.add(keras.layers.Conv2D(32,activation="relu",kernel_size=3,input_shape=(image_width, image_height, 3)))
model.add(keras.layers.MaxPooling2D((2,2),padding='same'))
model.add(keras.layers.Conv2D(64,activation="relu",kernel_size=3))
model.add(keras.layers.MaxPooling2D((2,2),padding='same'))
model.add(keras.layers.Conv2D(128,activation="relu",kernel_size=3))
model.add(keras.layers.MaxPooling2D((2,2),padding='same'))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(100,activation="relu"))
model.add(keras.layers.Dense(5,activation="softmax"))

# %% [markdown]
# Create model checkpoints

# %%
filepath = "./" + 'models/dalle_variations_rome_custom/dalle_variations_rome_custom_{epoch:02d}-{val_accuracy:.4f}.hdf5'
check_point = tf.keras.callbacks.ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,
                                                save_best_only=True, mode='max')

# %%
callbacks_list = [check_point]

# %%
model.compile(loss='categorical_crossentropy',
                  optimizer=keras.optimizers.RMSprop(learning_rate=2e-5),
                  metrics=['accuracy'])

# %%
history = model.fit(img_train,
                    steps_per_epoch=((len(img_train.filenames)) // batch_size), 
                    epochs=25,
                    validation_data=img_test, 
                    validation_steps=(len(img_test.filenames) // batch_size),
                    callbacks=callbacks_list)
# Out:
# Epoch 1/25
# 89/89 [==============================] - 25s 214ms/step - loss: 1.3773 - accuracy: 0.4404 - val_loss: 1.2105 - val_accuracy: 0.6458
#
# Epoch 00001: val_accuracy improved from -inf to 0.64583, saving model to ./models/dalle_variations_rome_custom\dalle_variations_rome_custom_01-0.6458.hdf5
# Epoch 2/25
# 89/89 [==============================] - 20s 220ms/step - loss: 1.0041 - accuracy: 0.6645 - val_loss: 1.0485 - val_accuracy: 0.6458
#
# Epoch 00002: val_accuracy did not improve from 0.64583
# Epoch 3/25
# 89/89 [==============================] - 14s 152ms/step - loss: 0.8244 - accuracy: 0.7099 - val_loss: 0.9997 - val_accuracy: 0.6667
#
# Epoch 00003: val_accuracy improved from 0.64583 to 0.66667, saving model to ./models/dalle_variations_rome_custom\dalle_variations_rome_custom_03-0.6667.hdf5
# Epoch 4/25
# 89/89 [==============================] - 13s 140ms/step - loss: 0.7396 - accuracy: 0.7270 - val_loss: 0.8850 - val_accuracy: 0.6250
#
# Epoch 00004: val_accuracy did not improve from 0.66667
# Epoch 5/25
# 89/89 [==============================] - 12s 140ms/step - loss: 0.6718 - accuracy: 0.7518 - val_loss: 0.8708 - val_accuracy: 0.6667
#
# Epoch 00005: val_accuracy did not improve from 0.66667
# Epoch 6/25
# 89/89 [==============================] - 13s 145ms/step - loss: 0.6366 - accuracy: 0.7574 - val_loss: 0.7294 - val_accuracy: 0.7292
#
# Epoch 00006: val_accuracy improved from 0.66667 to 0.72917, saving model to ./models/dalle_variations_rome_custom\dalle_variations_rome_custom_06-0.7292.hdf5
# Epoch 7/25
# 89/89 [==============================] - 12s 140ms/step - loss: 0.5976 - accuracy: 0.7837 - val_loss: 0.7037 - val_accuracy: 0.7500
#
# Epoch 00007: val_accuracy improved from 0.72917 to 0.75000, saving model to ./models/dalle_variations_rome_custom\dalle_variations_rome_custom_07-0.7500.hdf5
# Epoch 8/25
# 89/89 [==============================] - 13s 142ms/step - loss: 0.5775 - accuracy: 0.7936 - val_loss: 0.7147 - val_accuracy: 0.7292
#
# Epoch 00008: val_accuracy did not improve from 0.75000
# Epoch 9/25
# 89/89 [==============================] - 13s 141ms/step - loss: 0.5650 - accuracy: 0.7872 - val_loss: 0.6970 - val_accuracy: 0.7708
#
# Epoch 00009: val_accuracy improved from 0.75000 to 0.77083, saving model to ./models/dalle_variations_rome_custom\dalle_variations_rome_custom_09-0.7708.hdf5
# Epoch 10/25
# 89/89 [==============================] - 13s 141ms/step - loss: 0.5370 - accuracy: 0.8007 - val_loss: 0.6656 - val_accuracy: 0.7500
#
# Epoch 00010: val_accuracy did not improve from 0.77083
# Epoch 11/25
# 89/89 [==============================] - 13s 140ms/step - loss: 0.5159 - accuracy: 0.8078 - val_loss: 0.6063 - val_accuracy: 0.7500
#
# Epoch 00011: val_accuracy did not improve from 0.77083
# Epoch 12/25
# 89/89 [==============================] - 12s 139ms/step - loss: 0.4955 - accuracy: 0.8241 - val_loss: 0.5551 - val_accuracy: 0.8333
#
# Epoch 00012: val_accuracy improved from 0.77083 to 0.83333, saving model to ./models/dalle_variations_rome_custom\dalle_variations_rome_custom_12-0.8333.hdf5
# Epoch 13/25
# 89/89 [==============================] - 12s 139ms/step - loss: 0.5120 - accuracy: 0.8092 - val_loss: 0.5806 - val_accuracy: 0.8333
#
# Epoch 00013: val_accuracy did not improve from 0.83333
# Epoch 14/25
# 89/89 [==============================] - 12s 139ms/step - loss: 0.4822 - accuracy: 0.8340 - val_loss: 0.5752 - val_accuracy: 0.7708
#
# Epoch 00014: val_accuracy did not improve from 0.83333
# Epoch 15/25
# 89/89 [==============================] - 12s 139ms/step - loss: 0.4646 - accuracy: 0.8234 - val_loss: 0.5636 - val_accuracy: 0.7708
#
# Epoch 00015: val_accuracy did not improve from 0.83333
# Epoch 16/25
# 89/89 [==============================] - 12s 139ms/step - loss: 0.4436 - accuracy: 0.8326 - val_loss: 0.6026 - val_accuracy: 0.7917
#
# Epoch 00016: val_accuracy did not improve from 0.83333
# Epoch 17/25
# 89/89 [==============================] - 12s 140ms/step - loss: 0.4444 - accuracy: 0.8348 - val_loss: 0.5150 - val_accuracy: 0.8333
#
# Epoch 00017: val_accuracy did not improve from 0.83333
# Epoch 18/25
# 89/89 [==============================] - 12s 139ms/step - loss: 0.4288 - accuracy: 0.8426 - val_loss: 0.5583 - val_accuracy: 0.8542
#
# Epoch 00018: val_accuracy improved from 0.83333 to 0.85417, saving model to ./models/dalle_variations_rome_custom\dalle_variations_rome_custom_18-0.8542.hdf5
# Epoch 19/25
# 89/89 [==============================] - 12s 139ms/step - loss: 0.4342 - accuracy: 0.8291 - val_loss: 0.5178 - val_accuracy: 0.7708
#
# Epoch 00019: val_accuracy did not improve from 0.85417
# Epoch 20/25
# 89/89 [==============================] - 12s 138ms/step - loss: 0.4172 - accuracy: 0.8454 - val_loss: 0.4272 - val_accuracy: 0.8958
#
# Epoch 00020: val_accuracy improved from 0.85417 to 0.89583, saving model to ./models/dalle_variations_rome_custom\dalle_variations_rome_custom_20-0.8958.hdf5
# Epoch 21/25
# 89/89 [==============================] - 12s 139ms/step - loss: 0.4065 - accuracy: 0.8546 - val_loss: 0.5973 - val_accuracy: 0.7500
#
# Epoch 00021: val_accuracy did not improve from 0.89583
# Epoch 22/25
# 89/89 [==============================] - 12s 139ms/step - loss: 0.3983 - accuracy: 0.8489 - val_loss: 0.5666 - val_accuracy: 0.7500
#
# Epoch 00022: val_accuracy did not improve from 0.89583
# Epoch 23/25
# 89/89 [==============================] - 12s 139ms/step - loss: 0.3830 - accuracy: 0.8560 - val_loss: 0.4451 - val_accuracy: 0.8542
#
# Epoch 00023: val_accuracy did not improve from 0.89583
# Epoch 24/25
# 89/89 [==============================] - 12s 139ms/step - loss: 0.3844 - accuracy: 0.8567 - val_loss: 0.3903 - val_accuracy: 0.8333
#
# Epoch 00024: val_accuracy did not improve from 0.89583
# Epoch 25/25
# 89/89 [==============================] - 12s 139ms/step - loss: 0.3781 - accuracy: 0.8589 - val_loss: 0.3948 - val_accuracy: 0.8750
#
# Epoch 00025: val_accuracy did not improve from 0.89583

# %% [markdown]
# Evaluate model

# %%
plot_history(history)

# %% [markdown]
# Load best model

# %%
model = keras.models.load_model("./models/dalle_variations_rome_custom/dalle_variations_rome_custom_20-0.8958.hdf5")
pred = model.predict(img_test, steps=len(img_test.filenames))

# %%
keras.utils.plot_model(model)

# %%
evaluate_classification_result(img_test.classes, pred,classes=["foggy","cloudy","sunny","snowy","rainy"])
# Out:
# [[2 2 0 4 2]
#  [1 2 1 4 2]
#  [7 1 1 0 1]
#  [3 2 1 2 2]
#  [2 2 0 3 3]]
#
#
# Class foggy:
#     Sensitivity (TPR):  20.000% (2 of 10)
#     Specificity (TNR):  67.500% (27 of 40)
#     Precision:          13.333% (2 of 15)
#     Neg. pred. value:   77.143% (27 of 35)
# Class cloudy:
#     Sensitivity (TPR):  20.000% (2 of 10)
#     Specificity (TNR):  82.500% (33 of 40)
#     Precision:          22.222% (2 of 9)
#     Neg. pred. value:   80.488% (33 of 41)
# Class sunny:
#     Sensitivity (TPR):  10.000% (1 of 10)
#     Specificity (TNR):  95.000% (38 of 40)
#     Precision:          33.333% (1 of 3)
#     Neg. pred. value:   80.851% (38 of 47)
# Class snowy:
#     Sensitivity (TPR):  20.000% (2 of 10)
#     Specificity (TNR):  72.500% (29 of 40)
#     Precision:          15.385% (2 of 13)
#     Neg. pred. value:   78.378% (29 of 37)
# Class rainy:
#     Sensitivity (TPR):  30.000% (3 of 10)
#     Specificity (TNR):  82.500% (33 of 40)
#     Precision:          30.000% (3 of 10)
#     Neg. pred. value:   82.500% (33 of 40)
#
# Overall accuracy:   20.000% (10 of 50)
# Balanced accuracy:  20.000%
# array([[2, 2, 0, 4, 2],
#        [1, 2, 1, 4, 2],
#        [7, 1, 1, 0, 1],
#        [3, 2, 1, 2, 2],
#        [2, 2, 0, 3, 3]], dtype=int64)
